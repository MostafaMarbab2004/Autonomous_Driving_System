# %%
import sys
sys.path.append(r'E:\Carla_PPO_project_the.py')

from Simulation.connection import ClientConnection
from Simulation.enviroment import CarlaEnvironment

print("✅ Imports successful")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19416\2699180513.py in <module>
#       3
#       4 from Simulation.connection import ClientConnection
# ----> 5 from Simulation.enviroment import CarlaEnvironment
#       6
#       7 print("✅ Imports successful")
#
# E:\Carla_PPO_project_the.py\Simulation\enviroment.py in <module>
#      12 import random
#      13 import time
# ---> 14 from simulation.sensors import RGBCamera, LiDAR, CollisionSensor
#      15
#      16
#
# ModuleNotFoundError: No module named 'simulation'
